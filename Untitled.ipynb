# %%
import pandas as pd
import glob


path = "downloads/spike_2" # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame.to_csv("downloads/concat_spike_2.csv")

# %%
df = pd.read_csv("downloads/concat_spike_2.csv")

# %%
df
# Out:
#       Unnamed: 0  sentence_id  \
# 0              0       930451
# 1              1      1043919
# 2              2      2145159
# 3              3      2320416
# 4              4      3187462
# ...          ...          ...
# 8349        8349    361301445
# 8350        8350    361394043
# 8351        8351    361707629
# 8352        8352    361865653
# 8353        8353    362657513
#
#                                                   title  \
# 0     Outcomes from tandem mass spectrometry (MS/MS)...
# 1     Metabolism of Direct-acting Antiviral Agents (...
# 2     Cytochrome P450s: mechanisms and biological im...
# 3     Which organic acids does hemofiltrate contain ...
# 4                           Lactic acidosis: an update.
# ...                                                 ...
# 8349  Chemoprotection of murine hematopoietic cells ...
# 8350  Design, Synthesis and Evaluation of New Fluoro...
# 8351  Bacille Calmette-Guérin osteomyelitis of the p...
# 8352  Serum anti-p53 antibody detection in carcinoma...
# 8353     New aspects in the treatment of bone sarcomas.
#
#                                    article_link  \
# 0     https://pubmed.ncbi.nlm.nih.gov/15906714/
# 1     https://pubmed.ncbi.nlm.nih.gov/33319667/
# 2     https://pubmed.ncbi.nlm.nih.gov/25429675/
# 3     https://pubmed.ncbi.nlm.nih.gov/10654876/
# 4     https://pubmed.ncbi.nlm.nih.gov/27522622/
# ...                                         ...
# 8349  https://pubmed.ncbi.nlm.nih.gov/26651614/
# 8350  https://pubmed.ncbi.nlm.nih.gov/27250794/
# 8351  https://pubmed.ncbi.nlm.nih.gov/20519760/
# 8352  https://pubmed.ncbi.nlm.nih.gov/21277290/
# 8353   https://pubmed.ncbi.nlm.nih.gov/8587837/
#
#                                           sentence_text  year  \
# 0     Disorders of fatty acid oxidation and organic ...  2003
# 1     We present a comprehensive overview of specifi...  2021
# 2     Mostly different intermediate bioactive produc...  2014
# 3     It is not generally possible to measure most o...  1999
# 4     In this review , we provide a brief outline of...  2017
# ...                                                 ...   ...
# 8349  Transgenic (over)expression of chemotherapy re...  2015
# 8350  Malaria is one of the most important tropical ...  2016
# 8351  Clinical suspicion , early diagnosis using an ...  2010
# 8352  Although neoadjuvant chemotherapy ( NACT ) is ...  2011
# 8353  The response to the chemotherapy in osteosarco...  1994
#
#                                               mesh_list  \
# 0     ['Education, Medical, Continuing', 'Health Car...
# 1                                                    []
# 2     ['Animals', 'Biotransformation', 'Cytochrome P...
# 3     ['APACHE', 'Acetoacetates', 'analysis', 'Acids...
# 4     ['Acidosis, Lactic', 'physiopathology', 'Anima...
# ...                                                 ...
# 8349  ['ATP Binding Cassette Transporter, Subfamily ...
# 8350  ['Amodiaquine', 'analogs & derivatives', 'chem...
# 8351  ['BCG Vaccine', 'adverse effects', 'Diagnosis,...
# 8352  ['Adult', 'Aged', 'Aged, 80 and over', 'Antibo...
# 8353  ['Adolescent', 'Adult', 'Antineoplastic Combin...
#
#                                           journal_title      volume  issue  \
# 0     The Southeast Asian journal of tropical medici...  34 Suppl 3    NaN
# 1                               Current drug metabolism          22      2
# 2                               Current drug metabolism          15      7
# 3        The International journal of artificial organs          22     12
# 4            Clinical chemistry and laboratory medicine          55      3
# ...                                                 ...         ...    ...
# 8349  Journal of experimental & clinical cancer rese...          34    NaN
# 8350                 Chemical & pharmaceutical bulletin          64      6
# 8351  Hong Kong medical journal = Xianggang yi xue z...          16      3
# 8352  Clinica chimica acta; international journal of...         412  11-12
# 8353                              Acta medica Hungarica          50    3-4
#
#                                                abstract
# 0     Disorders of fatty acid oxidation and organic ...
# 1     Hepatitis C virus (HCV) infection is still one...
# 2     Cytochrome monooxygenases P450 enzymes (CYPs) ...
# 3     It is not generally possible to measure most o...
# 4     Lactate is one of the most crucial intermediat...
# ...                                                 ...
# 8349                                                NaN
# 8350                                                NaN
# 8351                                                NaN
# 8352                                                NaN
# 8353                                                NaN
#
# [8354 rows x 11 columns]
