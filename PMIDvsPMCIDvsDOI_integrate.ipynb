# %%
# !pip install metapub
# Out:
# Collecting metapub
#   Downloading metapub-0.5.5.tar.gz (120 kB)
#      |████████████████████████████████| 120 kB 26.3 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (49.6.0.post20210108)
# Requirement already satisfied: lxml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (4.6.4)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (2.26.0)
# Collecting eutils
#   Downloading eutils-0.6.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 1.1 MB/s
# Collecting habanero
#   Downloading habanero-1.0.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.9 MB/s
# Requirement already satisfied: tabulate in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (0.8.9)
# Collecting cssselect
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: unidecode in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (1.3.3)
# Requirement already satisfied: docopt in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (0.6.2)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (1.15.0)
# Collecting tox
#   Downloading tox-3.24.5-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 6.8 MB/s
# Requirement already satisfied: pytest in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from metapub) (6.2.2)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 7.0 MB/s
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 9.3 MB/s
#   Preparing metadata (setup.py) ... done
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 10.6 MB/s
# Requirement already satisfied: pytz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from eutils->metapub) (2021.1)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from habanero->metapub) (4.62.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->metapub) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->metapub) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->metapub) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->metapub) (2021.5.30)
# Requirement already satisfied: attrs>=19.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (20.3.0)
# Requirement already satisfied: iniconfig in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (1.1.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (21.3)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (1.10.0)
# Requirement already satisfied: toml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (0.10.2)
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->metapub) (3.7.0)
# Requirement already satisfied: filelock>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tox->metapub) (3.0.12)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.13.3-py2.py3-none-any.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 125.8 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->metapub) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->metapub) (3.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging->pytest->metapub) (2.4.7)
# Requirement already satisfied: platformdirs<3,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->metapub) (2.4.0)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 106.2 MB/s
# Collecting filelock>=3.0.0
#   Downloading filelock-3.4.1-py3-none-any.whl (9.9 kB)
# Collecting importlib-resources>=1.0
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Building wheels for collected packages: metapub, python-Levenshtein
#   Building wheel for metapub (setup.py) ... done
#   Created wheel for metapub: filename=metapub-0.5.5-py3-none-any.whl size=135366 sha256=fcab93a1a2de65451e989687eb6c087817f756933fc8cd77c271f41c0d8fd9e8
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4b/a9/fc/3df852b1e666a8fc6fe2721535f42d0be0098ae453d78ff84d
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp36-cp36m-linux_x86_64.whl size=155939 sha256=33c0582bd1f698d99cf543ed8c71a4a1377197e6dfd9fc48ce55220160fc9d60
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4a/a4/bf/d761b0899395c75fa76d003d607b3869ee47f5035b8afc30a2
# Successfully built metapub python-Levenshtein
# Installing collected packages: importlib-resources, filelock, distlib, virtualenv, humanfriendly, tox, python-Levenshtein, habanero, eutils, cssselect, coloredlogs, metapub
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.0.12
#     Uninstalling filelock-3.0.12:
#       Successfully uninstalled filelock-3.0.12
# Successfully installed coloredlogs-15.0.1 cssselect-1.1.0 distlib-0.3.4 eutils-0.6.0 filelock-3.4.1 habanero-1.0.0 humanfriendly-10.0 importlib-resources-5.4.0 metapub-0.5.5 python-Levenshtein-0.12.2 tox-3.24.5 virtualenv-20.13.3

# %%
#markus API key pubmed be67e0a1be023d17fff5334a6c6f45287a08

# %%
from metapub.convert import pmid2doi, PubMedFetcher,

# %%
# !export NCBI_API_KEY=be67e0a1be023d17fff5334a6c6f45287a08

# %%
from metapub.pubmedcentral import get_doi_for_otherid

# %%
import pandas as pd

df = pd.read_csv("downloads/58k_enriched_topic.csv")

# %%
df.columns
# Out:
# Index(['level_0', 'problem_id', 'title', 'article_link', 'text', 'mesh_list',
#        'journal_title', 'volume', 'issue', 'label', 'source', 'index', 'PMID',
#        'Title', 'Authors', 'Citation', 'First Author', 'Journal/Book',
#        'Publication Year', 'Create Date', 'PMCID', 'NIHMS ID', 'DOI',
#        'first_sent', 'predicts', 'sent_id', 'cluster_id', 'topic_id', 'probs',
#        'topic_name', 'closest_problem_id', 'doi', 'coreId', 'oai', 'len'],
#       dtype='object')

# %%
ta = " ".join(list(df[df.PMCID.notna()]["PMCID"]))

# %%
pmid = " ".join(list(df[df.PMID.notna()]["PMID"].map(round).map(str)))

# %%
df[df.PMCID.isna() & df.PMID.isna() & df.DOI.isna()]
# Out:
#        level_0  problem_id                                              title  \
# 0          NaN         NaN  Dextran Fractional Clearance Studies in Acute ...
# 2          NaN         NaN  Protein Synthesis Attenuation by Phosphorylati...
# 3          NaN         NaN  Mapping a gene for adult-onset primary open-an...
# 6          NaN         NaN  Cardiovascular Disease Risk Among the Poor and...
# 7          NaN         NaN  Analysis of peptidoglycan precursors in vancom...
# ...        ...         ...                                                ...
# 56886      NaN         NaN  Molecular cloning and characterization of a co...
# 56891      NaN         NaN  Rodent model of reproductive tract leiomyomata...
# 56892      NaN         NaN  Unexpected Death or Suicide by a Child or Adol...
# 56893      NaN         NaN                 RNAi for Plant Functional Genomics
# 56894      NaN         NaN  Metabolic Adaptations to Interrupted Glycosami...
#
#        article_link                                               text  \
# 0               NaN  Dengue is a potentially serious common viral i...
# 2               NaN  Chagas' disease is a potentially life-threaten...
# 3               NaN  Glaucoma is the third-leading cause of blindne...
# 6               NaN  Homelessness [and poverty] is rapidly escalati...
# 7               NaN  Vancomycin resistance in enterococci is an inc...
# ...             ...                                                ...
# 56886           NaN  Double-stranded cDNA has been synthesized from...
# 56891           NaN  Uterine myometrial tumors are the most commonl...
# 56892           NaN  The death of a young patient is a difficult bu...
# 56893           NaN  A major challenge in the post-genome era of pl...
# 56894           NaN  Lysosomal storage diseases (LSD) are metabolic...
#
#        mesh_list  journal_title  volume  issue  label  ... sent_id  \
# 0            NaN            NaN     NaN    NaN    NaN  ...     NaN
# 2            NaN            NaN     NaN    NaN    NaN  ...     NaN
# 3            NaN            NaN     NaN    NaN    NaN  ...     NaN
# 6            NaN            NaN     NaN    NaN    NaN  ...     NaN
# 7            NaN            NaN     NaN    NaN    NaN  ...     NaN
# ...          ...            ...     ...    ...    ...  ...     ...
# 56886        NaN            NaN     NaN    NaN    NaN  ...     NaN
# 56891        NaN            NaN     NaN    NaN    NaN  ...     NaN
# 56892        NaN            NaN     NaN    NaN    NaN  ...     NaN
# 56893        NaN            NaN     NaN    NaN    NaN  ...     NaN
# 56894        NaN            NaN     NaN    NaN    NaN  ...     NaN
#
#        cluster_id  topic_id            probs  \
# 0             NaN        22   [22, 102, 103]
# 2             NaN        40     [40, 39, 81]
# 3             NaN       348  [348, 301, 347]
# 6             NaN        -1  [413, 410, 397]
# 7             NaN       161  [161, 154, 162]
# ...           ...       ...              ...
# 56886         NaN       164  [163, 164, 152]
# 56891         NaN       173  [173, 172, 181]
# 56892         NaN       414  [427, 414, 369]
# 56893         NaN       163  [163, 164, 304]
# 56894         NaN       330  [330, 329, 326]
#
#                                           topic_name closest_problem_id  \
# 0                              dengue mosquito fever                NaN
# 2                           chagas cruzi trypanosoma                NaN
# 3                         retinal glaucoma blindness                NaN
# 6                      shortage physicians insurance                NaN
# 7                enterococci vancomycin enterococcus                NaN
# ...                                              ...                ...
# 56886                              pest crops blight                NaN
# 56891        endometrial endometriosis gynecological                NaN
# 56892                      dying terminally terminal                NaN
# 56893                     plant arabidopsis dormancy                NaN
# 56894  lysosomal aspartylglycosaminuria mannosidosis                NaN
#
#                           doi     coreId                                oai  \
# 0                         NaN  8608925.0  oai:pubmedcentral.nih.gov:3160290
# 2                         NaN  8644680.0  oai:pubmedcentral.nih.gov:3218062
# 3                         NaN  7466653.0  oai:pubmedcentral.nih.gov:1712411
# 6                         NaN  8366130.0  oai:pubmedcentral.nih.gov:2803292
# 7           10.1042/bj3010005  3671542.0  oai:pubmedcentral.nih.gov:1137133
# ...                       ...        ...                                ...
# 56886  10.1093/nar/10.24.7947  3399572.0   oai:pubmedcentral.nih.gov:327061
# 56891                     NaN  7604771.0  oai:pubmedcentral.nih.gov:1870894
# 56892                     NaN  8661200.0  oai:pubmedcentral.nih.gov:3244296
# 56893                     NaN  8108330.0  oai:pubmedcentral.nih.gov:2447448
# 56894                     NaN  8354060.0  oai:pubmedcentral.nih.gov:2785600
#
#       len
# 0      12
# 2      15
# 3      12
# 6      23
# 7      15
# ...    ..
# 56886  23
# 56891  12
# 56892  17
# 56893  23
# 56894  13
#
# [32693 rows x 35 columns]

# %%
with open("downloads/pmid2doi.json") as f:
    data = json.loads(f.read())
    #print(data['data'][0])

# %%
type(pmids[1])
# Out:
# float

# %%
pmids[:5]
# Out:
# [2665782.0, 24007234.0, 15129526.0, 2408189.0, 9431131.0]

# %%
pmid2doi('25902698.0')

# %%
import json
g = {}
already = data.keys()
pmids = list(df[df.PMID.notna()]["PMID"])

pmids = [pmid for pmid in pmids if str(pmid) not in data.keys()]
for idx, pmid in enumerate(pmids):
#     if str(pmid) in already:
#         pass
    print(pmid)
    pmid = str(pmid)
    if idx % 3 == 0:
        print("saving", idx, " of ", len(pmids)),
        with open("pmid2doi_2.json", "w") as f:
            f.write(json.dumps(g))
    
   
    try:
        doi = pmid2doi(pmid)
        g[pmid] = doi
        print(pmid, doi)
    except Exception as e:
        print("error", e)
# Out:
# 2665782.0
# saving 0  of  14972
# error 'NoneType' object is not subscriptable
# 24007234.0
# error 'NoneType' object is not subscriptable
# 15129526.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-22245a73a2c2> in <module>
#      17
#      18     try:
# ---> 19         doi = pmid2doi(pmid)
#      20         g[pmid] = doi
#      21         print(pmid, doi)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/metapub/convert.py in pmid2doi(pmid)
#      99         log.debug('PMID %s: Found DOI in MedLine XML.', pmid)
#     100         return pma.doi
# --> 101     return PubMedArticle2doi(pma)
#     102
#     103
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/metapub/convert.py in PubMedArticle2doi(pma)
#      72     _start_engines()
#      73
# ---> 74     work = cr_fetch.article_by_pma(pma)
#      75     if work:
#      76         log.debug('CrossRefWork found (%s) with Crossref score %i.', work.doi, work.score)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/metapub/crossref.py in article_by_pma(self, pma, ideal_ld, min_ld)
#     220         """
#     221         # Try with Title and Journal only
# --> 222         res = self.cr.works(query_title=pma.title, query_container_title=pma.journal, limit=5)
#     223         self.log.debug('PMID %s: Crossref Title/Journal query got %i results', pma.pmid, res['message']['total-results'])
#     224
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/habanero/crossref/crossref.py in works(self, ids, query, filter, offset, limit, sample, sort, order, facet, select, cursor, cursor_max, progress_bar, warn, **kwargs)
#     385                 progress_bar,
#     386                 **kwargs
# --> 387             ).do_request(should_warn=warn)
#     388
#     389     def members(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/habanero/request_class.py in do_request(self, should_warn)
#     102         payload = rename_query_filters(payload)
#     103
# --> 104         js = self._req(payload=payload, should_warn = should_warn)
#     105         if js is None:
#     106             return js
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/habanero/request_class.py in _req(self, payload, should_warn)
#     150                 self._url(),
#     151                 params=payload,
# --> 152                 headers=make_ua(self.mailto, self.ua_string),
#     153             )
#     154             r.raise_for_status()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in getresponse(self)
#    1377         try:
#    1378             try:
# -> 1379                 response.begin()
#    1380             except ConnectionError:
#    1381                 self.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# ~/anaconda3/envs/python3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
pmid2doi("27132035.0")
# Out:
# '10.1016/j.toxlet.2016.04.023'

# %%
5

# %%
df["PMCID"]

# %%
w = get_doi_for_otherid("7846491.0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-85a6f402fd4c> in <module>
# ----> 1 w = get_doi_for_otherid("7846491.0")
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/metapub/pubmedcentral.py in get_doi_for_otherid(otherid)
#      67     """
#      68     record = _pmc_id_conversion_api(otherid)
# ---> 69     return record.get('doi')
#      70
#      71
#
# AttributeError: 'NoneType' object has no attribute 'get'
